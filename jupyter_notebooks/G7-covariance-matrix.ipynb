# %% [markdown]
# # G7 covariance matrix
# Main Reference:
#
# * <a href=https://ftp.cs.ucla.edu/pub/stat_ser/r493.pdf>A Crash Course in Good and Bad Controls</a>,
# by Carlos Cinelli, Andrew Forney and Judea Pearl
#
# In this notebook, we derive, using a symbolic manipulator (SymPy), the covariance matrix and jacobian as a function of the gains, for
#
# ## G7
#
# This covariance matrix appears at the end of that paper.
#
# When $\underline{Z}$ is held fixed to a constant
# value $z$, we get $\langle \underline{Z},
# \underline{a}\rangle=0$
# for any node $\underline{a}$. Hence,
# for arbitrary nodes $\underline{a}$
# and $\underline{b}$,
# ratios such as
# $\langle \underline{Z},
# \underline{a}\rangle/\langle \underline{Z},
# \underline{b}\rangle$,
# are indefinite
# and can take on any value.
# If $\underline{Z}$ is a root
# node, then
# $\underline{Z}=\underline{\epsilon}_{\underline{Z}}$ so
# $0=\langle \underline{Z},\underline{Z}\rangle
# =
# \sigma^2_{\underline{\epsilon}_{\underline{Z}}}$.

# %%
# this makes sure it starts looking for things from the scumpy folder down.
import os
import sys
os.chdir('../')
sys.path.insert(0,os.getcwd())
print(os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\scumpy

# %%
from Graph import *
from CovMatCalculator import *

# %%
path = 'dot_atlas/good_bad_trols_G7.dot'
graph = Graph(path)
graph.draw(jupyter=True)

# %%
cal = CovMatCalculator(graph)
cal.calculate_cov_mat_sym()
cal.print_cov_mat_entries()
# Out:
# \begin{array}{l}
# \left\langle\underline{U1}, \underline{U1}\right\rangle=\sigma_{\underline{\epsilon}_{\underline{U1}}}^{2}
# \\
# \left\langle\underline{U1}, \underline{U2}\right\rangle=0
# \\
# \left\langle\underline{U1}, \underline{X}\right\rangle=\alpha_{\underline{X}|\underline{U1}} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2}
# \\
# \left\langle\underline{U1}, \underline{Z}\right\rangle=\alpha_{\underline{Z}|\underline{U1}} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2}
# \\
# \left\langle\underline{U1}, \underline{Y}\right\rangle=\alpha_{\underline{X}|\underline{U1}} \alpha_{\underline{Y}|\underline{X}} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2}
# \\
# \left\langle\underline{U2}, \underline{U1}\right\rangle=0
# \\
# \left\langle\underline{U2}, \underline{U2}\right\rangle=\sigma_{\underline{\epsilon}_{\underline{U2}}}^{2}
# \\
# \left\langle\underline{U2}, \underline{X}\right\rangle=0
# \\
# \left\langle\underline{U2}, \underline{Z}\right\rangle=\alpha_{\underline{Z}|\underline{U2}} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2}
# \\
# \left\langle\underline{U2}, \underline{Y}\right\rangle=\alpha_{\underline{Y}|\underline{U2}} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2}
# \\
# \left\langle\underline{X}, \underline{U1}\right\rangle=\alpha_{\underline{X}|\underline{U1}} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2}
# \\
# \left\langle\underline{X}, \underline{U2}\right\rangle=0
# \\
# \left\langle\underline{X}, \underline{X}\right\rangle=\alpha_{\underline{X}|\underline{U1}}^{2} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \sigma_{\underline{\epsilon}_{\underline{X}}}^{2}
# \\
# \left\langle\underline{X}, \underline{Z}\right\rangle=\alpha_{\underline{X}|\underline{U1}} \alpha_{\underline{Z}|\underline{U1}} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2}
# \\
# \left\langle\underline{X}, \underline{Y}\right\rangle=\alpha_{\underline{Y}|\underline{X}} \left(\alpha_{\underline{X}|\underline{U1}}^{2} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \sigma_{\underline{\epsilon}_{\underline{X}}}^{2}\right)
# \\
# \left\langle\underline{Z}, \underline{U1}\right\rangle=\alpha_{\underline{Z}|\underline{U1}} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2}
# \\
# \left\langle\underline{Z}, \underline{U2}\right\rangle=\alpha_{\underline{Z}|\underline{U2}} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2}
# \\
# \left\langle\underline{Z}, \underline{X}\right\rangle=\alpha_{\underline{X}|\underline{U1}} \alpha_{\underline{Z}|\underline{U1}} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2}
# \\
# \left\langle\underline{Z}, \underline{Z}\right\rangle=\alpha_{\underline{Z}|\underline{U1}}^{2} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \alpha_{\underline{Z}|\underline{U2}}^{2} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2} + \sigma_{\underline{\epsilon}_{\underline{Z}}}^{2}
# \\
# \left\langle\underline{Z}, \underline{Y}\right\rangle=\alpha_{\underline{X}|\underline{U1}} \alpha_{\underline{Y}|\underline{X}} \alpha_{\underline{Z}|\underline{U1}} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \alpha_{\underline{Y}|\underline{U2}} \alpha_{\underline{Z}|\underline{U2}} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2}
# \\
# \left\langle\underline{Y}, \underline{U1}\right\rangle=\alpha_{\underline{X}|\underline{U1}} \alpha_{\underline{Y}|\underline{X}} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2}
# \\
# \left\langle\underline{Y}, \underline{U2}\right\rangle=\alpha_{\underline{Y}|\underline{U2}} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2}
# \\
# \left\langle\underline{Y}, \underline{X}\right\rangle=\alpha_{\underline{Y}|\underline{X}} \left(\alpha_{\underline{X}|\underline{U1}}^{2} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \sigma_{\underline{\epsilon}_{\underline{X}}}^{2}\right)
# \\
# \left\langle\underline{Y}, \underline{Z}\right\rangle=\alpha_{\underline{X}|\underline{U1}} \alpha_{\underline{Y}|\underline{X}} \alpha_{\underline{Z}|\underline{U1}} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \alpha_{\underline{Y}|\underline{U2}} \alpha_{\underline{Z}|\underline{U2}} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2}
# \\
# \left\langle\underline{Y}, \underline{Y}\right\rangle=\alpha_{\underline{X}|\underline{U1}}^{2} \alpha_{\underline{Y}|\underline{X}}^{2} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \alpha_{\underline{Y}|\underline{U2}}^{2} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2} + \alpha_{\underline{Y}|\underline{X}}^{2} \sigma_{\underline{\epsilon}_{\underline{X}}}^{2} + \sigma_{\underline{\epsilon}_{\underline{Y}}}^{2}
# \end{array}

# %%
cal.print_jacobian_entries()
# Out:
# \begin{array}{l}
# \frac{\partial\underline{U1}}{\partial\underline{U1}}=1
# \\
# \frac{\partial\underline{U1}}{\partial\underline{U2}}=0
# \\
# \frac{\partial\underline{U1}}{\partial\underline{X}}=\frac{\alpha_{\underline{X}|\underline{U1}} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2}}{\alpha_{\underline{X}|\underline{U1}}^{2} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \sigma_{\underline{\epsilon}_{\underline{X}}}^{2}}
# \\
# \frac{\partial\underline{U1}}{\partial\underline{Z}}=\frac{\alpha_{\underline{Z}|\underline{U1}} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2}}{\alpha_{\underline{Z}|\underline{U1}}^{2} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \alpha_{\underline{Z}|\underline{U2}}^{2} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2} + \sigma_{\underline{\epsilon}_{\underline{Z}}}^{2}}
# \\
# \frac{\partial\underline{U1}}{\partial\underline{Y}}=\frac{\alpha_{\underline{X}|\underline{U1}} \alpha_{\underline{Y}|\underline{X}} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2}}{\alpha_{\underline{X}|\underline{U1}}^{2} \alpha_{\underline{Y}|\underline{X}}^{2} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \alpha_{\underline{Y}|\underline{U2}}^{2} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2} + \alpha_{\underline{Y}|\underline{X}}^{2} \sigma_{\underline{\epsilon}_{\underline{X}}}^{2} + \sigma_{\underline{\epsilon}_{\underline{Y}}}^{2}}
# \\
# \frac{\partial\underline{U2}}{\partial\underline{U1}}=0
# \\
# \frac{\partial\underline{U2}}{\partial\underline{U2}}=1
# \\
# \frac{\partial\underline{U2}}{\partial\underline{X}}=0
# \\
# \frac{\partial\underline{U2}}{\partial\underline{Z}}=\frac{\alpha_{\underline{Z}|\underline{U2}} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2}}{\alpha_{\underline{Z}|\underline{U1}}^{2} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \alpha_{\underline{Z}|\underline{U2}}^{2} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2} + \sigma_{\underline{\epsilon}_{\underline{Z}}}^{2}}
# \\
# \frac{\partial\underline{U2}}{\partial\underline{Y}}=\frac{\alpha_{\underline{Y}|\underline{U2}} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2}}{\alpha_{\underline{X}|\underline{U1}}^{2} \alpha_{\underline{Y}|\underline{X}}^{2} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \alpha_{\underline{Y}|\underline{U2}}^{2} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2} + \alpha_{\underline{Y}|\underline{X}}^{2} \sigma_{\underline{\epsilon}_{\underline{X}}}^{2} + \sigma_{\underline{\epsilon}_{\underline{Y}}}^{2}}
# \\
# \frac{\partial\underline{X}}{\partial\underline{U1}}=\alpha_{\underline{X}|\underline{U1}}
# \\
# \frac{\partial\underline{X}}{\partial\underline{U2}}=0
# \\
# \frac{\partial\underline{X}}{\partial\underline{X}}=1
# \\
# \frac{\partial\underline{X}}{\partial\underline{Z}}=\frac{\alpha_{\underline{X}|\underline{U1}} \alpha_{\underline{Z}|\underline{U1}} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2}}{\alpha_{\underline{Z}|\underline{U1}}^{2} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \alpha_{\underline{Z}|\underline{U2}}^{2} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2} + \sigma_{\underline{\epsilon}_{\underline{Z}}}^{2}}
# \\
# \frac{\partial\underline{X}}{\partial\underline{Y}}=\frac{\alpha_{\underline{Y}|\underline{X}} \left(\alpha_{\underline{X}|\underline{U1}}^{2} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \sigma_{\underline{\epsilon}_{\underline{X}}}^{2}\right)}{\alpha_{\underline{X}|\underline{U1}}^{2} \alpha_{\underline{Y}|\underline{X}}^{2} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \alpha_{\underline{Y}|\underline{U2}}^{2} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2} + \alpha_{\underline{Y}|\underline{X}}^{2} \sigma_{\underline{\epsilon}_{\underline{X}}}^{2} + \sigma_{\underline{\epsilon}_{\underline{Y}}}^{2}}
# \\
# \frac{\partial\underline{Z}}{\partial\underline{U1}}=\alpha_{\underline{Z}|\underline{U1}}
# \\
# \frac{\partial\underline{Z}}{\partial\underline{U2}}=\alpha_{\underline{Z}|\underline{U2}}
# \\
# \frac{\partial\underline{Z}}{\partial\underline{X}}=\frac{\alpha_{\underline{X}|\underline{U1}} \alpha_{\underline{Z}|\underline{U1}} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2}}{\alpha_{\underline{X}|\underline{U1}}^{2} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \sigma_{\underline{\epsilon}_{\underline{X}}}^{2}}
# \\
# \frac{\partial\underline{Z}}{\partial\underline{Z}}=1
# \\
# \frac{\partial\underline{Z}}{\partial\underline{Y}}=\frac{\alpha_{\underline{X}|\underline{U1}} \alpha_{\underline{Y}|\underline{X}} \alpha_{\underline{Z}|\underline{U1}} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \alpha_{\underline{Y}|\underline{U2}} \alpha_{\underline{Z}|\underline{U2}} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2}}{\alpha_{\underline{X}|\underline{U1}}^{2} \alpha_{\underline{Y}|\underline{X}}^{2} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \alpha_{\underline{Y}|\underline{U2}}^{2} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2} + \alpha_{\underline{Y}|\underline{X}}^{2} \sigma_{\underline{\epsilon}_{\underline{X}}}^{2} + \sigma_{\underline{\epsilon}_{\underline{Y}}}^{2}}
# \\
# \frac{\partial\underline{Y}}{\partial\underline{U1}}=\alpha_{\underline{X}|\underline{U1}} \alpha_{\underline{Y}|\underline{X}}
# \\
# \frac{\partial\underline{Y}}{\partial\underline{U2}}=\alpha_{\underline{Y}|\underline{U2}}
# \\
# \frac{\partial\underline{Y}}{\partial\underline{X}}=\alpha_{\underline{Y}|\underline{X}}
# \\
# \frac{\partial\underline{Y}}{\partial\underline{Z}}=\frac{\alpha_{\underline{X}|\underline{U1}} \alpha_{\underline{Y}|\underline{X}} \alpha_{\underline{Z}|\underline{U1}} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \alpha_{\underline{Y}|\underline{U2}} \alpha_{\underline{Z}|\underline{U2}} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2}}{\alpha_{\underline{Z}|\underline{U1}}^{2} \sigma_{\underline{\epsilon}_{\underline{U1}}}^{2} + \alpha_{\underline{Z}|\underline{U2}}^{2} \sigma_{\underline{\epsilon}_{\underline{U2}}}^{2} + \sigma_{\underline{\epsilon}_{\underline{Z}}}^{2}}
# \\
# \frac{\partial\underline{Y}}{\partial\underline{Y}}=1
# \end{array}
